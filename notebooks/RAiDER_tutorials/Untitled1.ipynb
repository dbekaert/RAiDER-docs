# %%
import datetime
import pyproj
import xarray
import matplotlib

matplotlib.use('qtagg')

import numpy as np
import matplotlib.pyplot as plt

# %%
import RAiDER
import os

# %%
from RAiDER.models.merra2 import MERRA2

# %%
# First define datetime, and AOI
date_time = datetime.datetime(2018,11,13, 23, 0, 0)

# bounding box is given in SNWE format
ll_bounds = [36.8, 36.85, -76.15, -76.05]

# %%
from RAiDER.processWM import prepareWeatherModel

# %%
weather_model = MERRA2()

# %%
prepareWeatherModel(weather_model, date_time, ll_bounds=ll_bounds, makePlots=True)
# Out:
# Weather model MERRA2 is available from 1980-01-01 to Present
# Number of weather model nodes: 5075
# Shape of weather model: (5, 7, 145)
# Bounds of the weather model: 35.50/37.50/-78.12/-74.38 (SNWE)
# Weather model: MERRA2
# Mean value of the wet refractivity: 17.733688
# Mean value of the hydrostatic refractivity: 107.472404
#
# ======Weather Model class object=====
# Weather model time: 2018-11-13 23:00:00
# Latitude resolution: 0.5
# Longitude resolution: 0.625
# Native projection: EPSG:4326
# ZMIN: -100.0
# ZMAX: 26000.0
# k1 = 0.776
# k2 = 0.233
# k3 = 3750.0
# Humidity type = q
# =====================================
# Class name: merra2
# Dataset: merra2
# =====================================
# A: []
# B: []
# Number of points in Lon/Lat = 5/7
# Total number of grid points (3D): 5075
# =====================================
#
# ERROR: Unable to save weathermodel to file
# Traceback (most recent call last):
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 132, in as_variable
#     obj = Variable(*obj)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 367, in __init__
#     self._dims = self._parse_dimensions(dims)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 682, in _parse_dimensions
#     raise ValueError(
# ValueError: dimensions ('y', 'x') must have the same length as the number of data dimensions, ndim=3
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jlmd9g/software/RAiDER/tools/RAiDER/processWM.py", line 127, in prepareWeatherModel
#     f = weather_model.write()
#   File "/Users/jlmd9g/software/RAiDER/tools/RAiDER/models/weatherModel.py", line 766, in write
#     ds = xarray.Dataset(data_vars=dataset_dict, coords=dimension_dict, attrs=attrs_dict)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/dataset.py", line 641, in __init__
#     variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/merge.py", line 561, in merge_data_and_coords
#     indexes, coords = _create_indexes_from_coords(coords, data_vars)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/merge.py", line 595, in _create_indexes_from_coords
#     variable = as_variable(obj, name=name)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 135, in as_variable
#     raise error.__class__(
# ValueError: Could not convert tuple of form (dims, data[, attrs, encoding]): (('y', 'x'), array([[[35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         ...,
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5]],
#
#        [[36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         ...,
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ]],
#
#        [[36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         ...,
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5]],
#
#        [[37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         ...,
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ]],
#
#        [[37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         ...,
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5]]])) to Variable.
# ERROR: Could not convert tuple of form (dims, data[, attrs, encoding]): (('y', 'x'), array([[[35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         ...,
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5]],
#
#        [[36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         ...,
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ]],
#
#        [[36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         ...,
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5]],
#
#        [[37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         ...,
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ]],
#
#        [[37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         ...,
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5]]])) to Variable.
# Traceback (most recent call last):
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 132, in as_variable
#     obj = Variable(*obj)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 367, in __init__
#     self._dims = self._parse_dimensions(dims)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 682, in _parse_dimensions
#     raise ValueError(
# ValueError: dimensions ('y', 'x') must have the same length as the number of data dimensions, ndim=3
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/jlmd9g/software/RAiDER/tools/RAiDER/processWM.py", line 127, in prepareWeatherModel
#     f = weather_model.write()
#   File "/Users/jlmd9g/software/RAiDER/tools/RAiDER/models/weatherModel.py", line 766, in write
#     ds = xarray.Dataset(data_vars=dataset_dict, coords=dimension_dict, attrs=attrs_dict)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/dataset.py", line 641, in __init__
#     variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/merge.py", line 561, in merge_data_and_coords
#     indexes, coords = _create_indexes_from_coords(coords, data_vars)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/merge.py", line 595, in _create_indexes_from_coords
#     variable = as_variable(obj, name=name)
#   File "/Users/jlmd9g/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py", line 135, in as_variable
#     raise error.__class__(
# ValueError: Could not convert tuple of form (dims, data[, attrs, encoding]): (('y', 'x'), array([[[35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         ...,
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5]],
#
#        [[36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         ...,
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ]],
#
#        [[36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         ...,
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5]],
#
#        [[37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         ...,
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ]],
#
#        [[37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         ...,
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5]]])) to Variable.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py:132, in as_variable(obj, name)
#     131 try:
# --> 132     obj = Variable(*obj)
#     133 except (TypeError, ValueError) as error:
#     134     # use .format() instead of % because it handles tuples consistently
#
# File ~/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py:367, in Variable.__init__(self, dims, data, attrs, encoding, fastpath)
#     366 self._data = as_compatible_data(data, fastpath=fastpath)
# --> 367 self._dims = self._parse_dimensions(dims)
#     368 self._attrs = None
#
# File ~/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py:682, in Variable._parse_dimensions(self, dims)
#     681 if len(dims) != self.ndim:
# --> 682     raise ValueError(
#     683         f"dimensions {dims} must have the same length as the "
#     684         f"number of data dimensions, ndim={self.ndim}"
#     685     )
#     686 return dims
#
# ValueError: dimensions ('y', 'x') must have the same length as the number of data dimensions, ndim=3
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/software/RAiDER/tools/RAiDER/processWM.py:127, in prepareWeatherModel(***failed resolving arguments***)
#     126 try:
# --> 127     f = weather_model.write()
#     128     containment = weather_model.checkContainment(ll_bounds)
#
# File ~/software/RAiDER/tools/RAiDER/models/weatherModel.py:766, in WeatherModel.write(self)
#     756 dataset_dict = {
#     757     't': (('z', 'y', 'x'), self._t.swapaxes(0, 2).swapaxes(1, 2)),
#     758     'p': (('z', 'y', 'x'), self._p.swapaxes(0, 2).swapaxes(1, 2)),
#    (...)
#     763     'hydro_total': (('z', 'y', 'x'), self._hydrostatic_ztd.swapaxes(0, 2).swapaxes(1, 2)),
#     764 }
# --> 766 ds = xarray.Dataset(data_vars=dataset_dict, coords=dimension_dict, attrs=attrs_dict)
#     768 # Define units
#
# File ~/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/dataset.py:641, in Dataset.__init__(self, data_vars, coords, attrs)
#     639     coords = coords.variables
# --> 641 variables, coord_names, dims, indexes, _ = merge_data_and_coords(
#     642     data_vars, coords, compat="broadcast_equals"
#     643 )
#     645 self._attrs = dict(attrs) if attrs is not None else None
#
# File ~/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/merge.py:561, in merge_data_and_coords(data_vars, coords, compat, join)
#     560 """Used in Dataset.__init__."""
# --> 561 indexes, coords = _create_indexes_from_coords(coords, data_vars)
#     562 objects = [data_vars, coords]
#
# File ~/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/merge.py:595, in _create_indexes_from_coords(coords, data_vars)
#     594 for name, obj in index_vars.items():
# --> 595     variable = as_variable(obj, name=name)
#     597     if variable.dims == (name,):
#
# File ~/software/mambaforge/envs/RAiDER/lib/python3.10/site-packages/xarray/core/variable.py:135, in as_variable(obj, name)
#     133     except (TypeError, ValueError) as error:
#     134         # use .format() instead of % because it handles tuples consistently
# --> 135         raise error.__class__(
#     136             "Could not convert tuple of form "
#     137             "(dims, data[, attrs, encoding]): "
#     138             "{} to Variable.".format(obj)
#     139         )
#     140 elif utils.is_scalar(obj):
#
# ValueError: Could not convert tuple of form (dims, data[, attrs, encoding]): (('y', 'x'), array([[[35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         ...,
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5],
#         [35.5, 35.5, 35.5, ..., 35.5, 35.5, 35.5]],
#
#        [[36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         ...,
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ],
#         [36. , 36. , 36. , ..., 36. , 36. , 36. ]],
#
#        [[36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         ...,
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5],
#         [36.5, 36.5, 36.5, ..., 36.5, 36.5, 36.5]],
#
#        [[37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         ...,
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ],
#         [37. , 37. , 37. , ..., 37. , 37. , 37. ]],
#
#        [[37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         ...,
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5],
#         [37.5, 37.5, 37.5, ..., 37.5, 37.5, 37.5]]])) to Variable.
#
# During handling of the above exception, another exception occurred:
#
# CriticalError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 prepareWeatherModel(weather_model, date_time, ll_bounds=ll_bounds, makePlots=True)
#
# File ~/software/RAiDER/tools/RAiDER/processWM.py:133, in prepareWeatherModel(***failed resolving arguments***)
#     131     logger.exception("Unable to save weathermodel to file")
#     132     logger.exception(e)
# --> 133     raise CriticalError
#     135 finally:
#     136     wm = weather_model.Model()
#
# CriticalError: I have experienced a critical error, please take a look at the log files
